# %%
import nltk 
from nltk.corpus import stopwords
nltk.download('omw-1.4')
nltk.download('wordnet')
from nltk.corpus import wordnet as wn

from nx_graph_utils import closure_graph, draw_text_graph
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Usuario\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Usuario\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Ejemplo Synsets con Carro

# %%
# synset: grupo de sinómimos de una palabra.
ss = wn.synsets('carro', lang='spa')
ss
# Out:
# [Synset('car.n.01'),
#  Synset('carriage.n.04'),
#  Synset('carrier.n.02'),
#  Synset('cart.n.01'),
#  Synset('chariot.n.02'),
#  Synset('cartload.n.01')]

# %%
# explorando los synsets
for syn in ss:
  print(syn.name(), ': ', syn.definition())
  for name in syn.lemma_names():
    print(' * ', name)
# Out:
# car.n.01 :  a motor vehicle with four wheels; usually propelled by an internal combustion engine
#  *  car
#  *  auto
#  *  automobile
#  *  machine
#  *  motorcar
# carriage.n.04 :  a machine part that carries something else
#  *  carriage
# carrier.n.02 :  a self-propelled wheeled vehicle designed specifically to carry something
#  *  carrier
# cart.n.01 :  a heavy open wagon usually having two wheels and drawn by an animal
#  *  cart
# chariot.n.02 :  a two-wheeled horse-drawn battle vehicle; used in war and races in ancient Egypt and Greece and Rome
#  *  chariot
# cartload.n.01 :  the quantity that a cart holds
#  *  cartload

# %%
print(ss[0].name())
G, labels = closure_graph(ss[0], fn = lambda s: s.hyponyms())
draw_text_graph(G, labels)
# Out:
# car.n.01

# %%
print(ss[0].name())
G, labels = closure_graph(ss[0], fn = lambda s: s.hypernyms())
draw_text_graph(G, labels)
# Out:
# car.n.01

# %% [markdown]
# # Synsets con otros

# %%
# synset: grupo de sinómimos de una palabra.
ss = wn.synsets('python', lang='eng')
ss
# Out:
# [Synset('python.n.01'), Synset('python.n.02'), Synset('python.n.03')]

# %%
# explorando los synsets
for syn in ss:
  print(syn.name(), ': ', syn.definition())
  for name in syn.lemma_names():
    print(' * ', name)
# Out:
# python.n.01 :  large Old World boas
#  *  python
# python.n.02 :  a soothsaying spirit or a person who is possessed by such a spirit
#  *  python
# python.n.03 :  (Greek mythology) dragon killed by Apollo at Delphi
#  *  Python

# %%
n = 0
print(ss[n].name())
G, labels = closure_graph(ss[n], fn = lambda s: s.hyponyms())
draw_text_graph(G, labels)
# Out:
# python.n.01

# %%
print(ss[n].name())
G, labels = closure_graph(ss[n], fn = lambda s: s.hypernyms())
draw_text_graph(G, labels)
# Out:
# python.n.01
