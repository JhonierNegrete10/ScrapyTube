# %% [markdown]
# # load data frame

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import matplotlib
from wordcloud import WordCloud, STOPWORDS
from scraping_utils import read_json, flatten_list

# %%
df = pd.read_csv('data_videos/dataframes/data.csv' )
df.head(5)
# Out:
#                                         titulo_video  \
# 0  AMT2 - Extracting Emails from your Gmail Inbox...
# 1       Read emails with Python + Gmail API (part 1)
# 2  Logra Más Con Menos Esfuerzo - Esencialismo de...
# 3  Estratégia de trading con ChatGPT 4 Code Inter...
# 4  AI & Machine Learning in Finance: AI Applicati...
#
#                nombre_canal  \
# 0             DigitalSreeni
# 1                 ian samir
# 2      Mis Propias Finanzas
# 3            Rodrigo Prieto
# 4  Swedish House of Finance
#
#                                             keywords lngs  \
# 0  ['amt2', 'extracting', 'emails', 'gmail', 'inb...   en
# 1  ['read', 'emails', 'python', 'gmail', 'api', '...   en
# 2  ['logra', 'menos', 'esfuerzo', 'esencialismo',...   es
# 3  ['estratégia', 'trading', 'chatgpt', '4', 'cod...   es
# 4  ['ai', 'machine', 'learning', 'finance', 'ai',...   en
#
#                                              bigrams  \
# 0  [('amt2', 'extracting'), ('extracting', 'email...
# 1  [('read', 'emails'), ('emails', 'python'), ('p...
# 2  [('logra', 'menos'), ('menos', 'esfuerzo'), ('...
# 3  [('estratégia', 'trading'), ('trading', 'chatg...
# 4  [('ai', 'machine'), ('machine', 'learning'), (...
#
#                                             trigrams
# 0  [('amt2', 'extracting', 'emails'), ('extractin...
# 1  [('read', 'emails', 'python'), ('emails', 'pyt...
# 2  [('logra', 'menos', 'esfuerzo'), ('menos', 'es...
# 3  [('estratégia', 'trading', 'chatgpt'), ('tradi...
# 4  [('ai', 'machine', 'learning'), ('machine', 'l...

# %%
# Combinar todas las palabras en una sola cadena
all_keywords = df['keywords'].to_list()
all_keywords = [eval(item) for item in all_keywords]
all_keywords = flatten_list(all_keywords)
all_keywords = ' '.join(all_keywords)
all_keywords
# Out:
# 'amt2 extracting emails gmail inbox using python read emails python gmail api part 1 logra menos esfuerzo esencialismo greg mckeown estratégia trading chatgpt 4 code interpreter ai machine learning finance ai applications financial industry panel discussion diy thermal camera using amg8833 thermal image array temperature sensor raspberry pi alain botton educación emocional react ecosystem 2023 potenciar eficiencia procesos ingeniería fases diseño fabricación webinar edificios energía casi nula reto eficiencia energética españa webinar eficiencia energética edificios 7 octubre 2015 votimum webinar completo integración programación proyectos smart home tiempo récord webinar completo energía fotovoltaica autoconsumo ventiladores rejillas teknopowers finder altech medidores humedad igm marca flir webinar sistema comunicación marca autonics webinar selección aplicaciones plc hmi conexiones entradas salidas medidor humedad imágenes termográficas teledyne flir mr160 9 free notion templates 10x productivity build face recognition tool python link code react js tutorial basic advance 2023 10 principios estoicos construir marco aurelio cafetera italiana mejorar café reinventarse invertir vida superar miedo mario alonso puig second brain notion template proyecto data science python proyecto completo 0 problema economía canadá diseñando base datos similar medium rpa 5 minutes rpa robotic process automation rpa explained simplilearn simple file management system changed life robotics software engineer roadmap need master robotics perfect home server 2023 48tb 4x lan 18w quiet compact restrepo explica perdiendo inteligencia revertirlo escala independencia financiera 10 niveles notion api python español rethinking pkm organize everything obsidian arquitectura software código limpio programador senior platzi raw radio 18 ft manuel zapata take smart notes book page develop superpower constructive debating dialog mapping includes chatgpt case study visualize options guide using flowcharts digest read walkthrough process understanding rationality eliezer yudkowsky mastering concept visualizations simple workflow creating effective visuals folders links key filosofía estoica epicteto estoicismo 12 attractive hobbies guys try make cli tools extract data click modern html scraping pythons best tools use notion task manager dependencies tutorial inside ali abdaal second brain system spinoza filósofo maldito racionalismo filosofía moderna 10 udemy courses every developer coding cuantas horas ayuno necesito bajar peso ayuno intermitente use websockets try custom swipe animation flutter speed code credit card app part 2 useeffect mistakes every junior react developer makes never ask pointers watching video made fast file explorer rust critiquing ai startup websites yc president garry tan build cloud identity access management really wants know orca model saw coming build notion task manager 3 recurring tasks project templates dark side wireless networks intro hacking megi bashi ryan dinnan google system design interview design spotify em todas webcams high frequency trading notation coding interviews every good programmer know code data structure easy pointers c full course tutorial cuda programming python numba cupy complete course layout design master layout 00 chomsky quién domina mundo introducción mejore gestión infraestructura python snippets 1 minute ruta ser programador normal talk design payment system system design interview suzuki gixxer 250 vs yamaha fz 25 comparativa precio motor diseño características build ai document chatbot 10 minutes spinoza dios leyes naturaleza dra ana minecan vector databases simply explained embeddings indexes let build trello react drag drop zustand appwrite cloud ts definir reglas arquitectura hexagonal ddd código proyecto teoria grafos asistente virtual definitivo langchain notion modo sábelo activado parte 4 2 principios arquitectura software haz trabajo hora 8 minutos ia estudiantes universitarios mindset cha ...

# %%
# Crear un objeto WordCloud
wordcloud = WordCloud(width=800, height=800,
                      background_color='white',
                      min_font_size=10,
                      colormap='viridis'
                      
                      ).generate(all_keywords)

# Mostrar la nube de palabras utilizando matplotlib
plt.figure(figsize=(8, 8), facecolor=None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)

plt.show()

# %% [markdown]
# graph nx

# %%
# import networkx as nx
# import matplotlib.pyplot as plt

# # Crear un gráfico de relaciones
# G = nx.Graph()
# for cluster in range(num_clusters):
#     cluster_videos = df1[df1['cluster'] == cluster]
#     for index, video in cluster_videos.iterrows():
#         G.add_node(video['titulo_video'])
#         for neighbor in cluster_videos.iterrows():
#             G.add_edge(video['titulo_video'], neighbor[1]['titulo_video'])

# # Dibujar el gráfico
# pos = nx.spring_layout(G, seed=42)
# nx.draw(G, pos, with_labels=True, font_weight='bold')
# plt.show()
